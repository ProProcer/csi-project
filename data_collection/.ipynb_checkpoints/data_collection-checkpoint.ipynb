# %%
import serial
import csv
import os
from datetime import datetime, timedelta
import time
from pathlib import Path

# %%
def reset_esp32(port, baudrate=921600):
    """Resets an ESP32 using the RTS and DTR lines of the serial port.

    Args:
        port: The serial port (e.g., "COM3" on Windows, "/dev/ttyUSB0" on Linux).
        baudrate: The baud rate (typically 115200 for communication,
                  but can be higher for flashing).
    """
    try:
        with serial.Serial(port, baudrate) as ser:
            # Method 1 (esptool.py compatible):
            ser.dtr = False  # DTR = 0: Set EN (reset) to HIGH
            ser.rts = True   # RTS = 1, Set IO0 (GPIO0) to LOW: BOOT mode
            time.sleep(0.1)
            ser.dtr = True   # DTR = 1, Set EN to LOW: Reset chip
            time.sleep(0.1)  # Wait for the chip to reset
            ser.dtr = False  # DTR = 0, set EN to HIGH
            ser.rts = False # Set IO0 to HIGH, back to normal mode.
            time.sleep(0.1)

            # Method 2 (Simple DTR toggle - might work in some cases):
            # ser.dtr = True   # Assert DTR (often connected to reset)
            # time.sleep(0.1)
            # ser.dtr = False  # De-assert DTR
            # time.sleep(0.1)
            print(f"ESP32 reset via DTR/RTS on port {port}")

    except serial.SerialException as e:
        print(f"Error resetting ESP32: {e}")

# %%
def collect_csi_data(filepath, port, baudrate = 921600, seconds = 100, minutes = 0, hours = 0, temp_data = False):
    with serial.Serial(port, baudrate) as ser:
        header = "type,seq,mac,rssi,rate,sig_mode,mcs,bandwidth,smoothing,not_sounding,aggregation,stbc,fec_coding,sgi,noise_floor,ampdu_cnt,channel,secondary_channel,local_timestamp,ant,sig_len,rx_state,len,first_word,data,datetime"
        
        start_time = datetime.now()
        
        filename = filepath
        if temp_data:
            temp_file_path = temp_data
        
        if not os.path.exists(filename):
            with open(filename, 'w', encoding = 'utf-8') as f:
                f.write(header + '\n')
                
        
        
        num_collected = 0

        end_time = timedelta(seconds = seconds, minutes = minutes, hours = hours)
        
        if ser.in_waiting > 0:
            ser.reset_input_buffer()
        
        while (datetime.now() - start_time) <= end_time:
            if ser.in_waiting > 0:
                try:
                    line = ser.readline().decode('utf-8').strip()
                except:
                    print("DECODE FAILED")
                    continue
                line = line + f',{datetime.now()}'
                if not line.startswith("CSI_DATA"):
                    continue
                with open(filename, 'a', newline = '', encoding = 'utf-8') as f:
                    f.write(line + '\n')       
        
                num_collected += 1

                if temp_data:
                    if num_collected % 5 == 0:
                        with open(temp_file_path, 'w', newline = '', encoding = 'utf-8') as f:
                            f.write(header + '\n')
                            f.write(line + '\n')  
                
                if num_collected % 100 == 0:
                    print(f"{datetime.now()} Number of CSI data collected : {num_collected}")
                    print(f"ser_inwaiting : {ser.in_waiting}")
        if temp_data:
            os.remove(temp_file_path)
        
        print(f"Total : {num_collected}")

# %%
def collect_csi_data_by_num(filepath, port, total_data, baudrate = 921600, temp_data = False):
    with serial.Serial(port, baudrate) as ser:
        header = "type,seq,mac,rssi,rate,sig_mode,mcs,bandwidth,smoothing,not_sounding,aggregation,stbc,fec_coding,sgi,noise_floor,ampdu_cnt,channel,secondary_channel,local_timestamp,ant,sig_len,rx_state,len,first_word,data,datetime"
        
        start_time = datetime.now()
        
        filename = filepath
        if temp_data:
            temp_file_path = temp_data
        
        if not os.path.exists(filename):
            with open(filename, 'w', encoding = 'utf-8') as f:
                f.write(header + '\n')
                
        
        
        num_collected = 0

        if ser.in_waiting > 0:
            ser.reset_input_buffer()
        
        while num_collected <= total_data:
            if ser.in_waiting > 0:
                try:
                    line = ser.readline().decode('utf-8').strip()
                except:
                    print("DECODE FAILED")
                    continue
                line = line + f',{datetime.now()}'
                if not line.startswith("CSI_DATA"):
                    continue
                with open(filename, 'a', newline = '', encoding = 'utf-8') as f:
                    f.write(line + '\n')       
        
                num_collected += 1

                if temp_data:
                    if num_collected % 5 == 0:
                        with open(temp_file_path, 'w', newline = '', encoding = 'utf-8') as f:
                            f.write(header + '\n')
                            f.write(line + '\n')  
                
                if num_collected % 100 == 0:
                    print(f"{datetime.now()} Number of CSI data collected : {num_collected}")
                    print(f"ser_inwaiting : {ser.in_waiting}")
        if temp_data:
            os.remove(temp_file_path)
        
        print(f"Total : {num_collected}")

# %%
PORT = "COM8"
BAUDRATE = "921600"
FILEPATH = r"D:\Matthew\SelfStudy\csi-project\csi-project\data_collection\makerspace_12_04_2025\valid\valid_stand1.csv"


reset_esp32(PORT, BAUDRATE)
for i in range(15):
    print(f"start in {15-i}")
    time.sleep(1)
collect_csi_data_by_num(FILEPATH, PORT, total_data =6000, baudrate = BAUDRATE)
# Out:
# ESP32 reset via DTR/RTS on port COM8
# start in 15
# start in 14
# start in 13
# start in 12
# start in 11
# start in 10
# start in 9
# start in 8
# start in 7
# start in 6
# start in 5
# start in 4
# start in 3
# start in 2
# start in 1
# 2025-04-12 16:01:51.185289 Number of CSI data collected : 100
# ser_inwaiting : 0
# 2025-04-12 16:01:55.363242 Number of CSI data collected : 200
# ser_inwaiting : 0
# 2025-04-12 16:01:59.869574 Number of CSI data collected : 300
# ser_inwaiting : 544
# 2025-04-12 16:02:04.445990 Number of CSI data collected : 400
# ser_inwaiting : 0
# 2025-04-12 16:02:09.341915 Number of CSI data collected : 500
# ser_inwaiting : 0
# 2025-04-12 16:02:13.520466 Number of CSI data collected : 600
# ser_inwaiting : 0
# 2025-04-12 16:02:17.847965 Number of CSI data collected : 700
# ser_inwaiting : 128
# 2025-04-12 16:02:22.324380 Number of CSI data collected : 800
# ser_inwaiting : 0
# 2025-04-12 16:02:26.709399 Number of CSI data collected : 900
# ser_inwaiting : 0
# 2025-04-12 16:02:31.026932 Number of CSI data collected : 1000
# ser_inwaiting : 0
# 2025-04-12 16:02:35.719882 Number of CSI data collected : 1100
# ser_inwaiting : 0
# 2025-04-12 16:02:40.105631 Number of CSI data collected : 1200
# ser_inwaiting : 0
# 2025-04-12 16:02:44.560443 Number of CSI data collected : 1300
# ser_inwaiting : 0
# 2025-04-12 16:02:49.082568 Number of CSI data collected : 1400
# ser_inwaiting : 0
# 2025-04-12 16:02:53.502044 Number of CSI data collected : 1500
# ser_inwaiting : 0
# 2025-04-12 16:02:57.854282 Number of CSI data collected : 1600
# ser_inwaiting : 0
# 2025-04-12 16:03:02.341625 Number of CSI data collected : 1700
# ser_inwaiting : 0
# 2025-04-12 16:03:06.535153 Number of CSI data collected : 1800
# ser_inwaiting : 0
# 2025-04-12 16:03:10.808072 Number of CSI data collected : 1900
# ser_inwaiting : 0
# 2025-04-12 16:03:15.182140 Number of CSI data collected : 2000
# ser_inwaiting : 1024
# 2025-04-12 16:03:19.342982 Number of CSI data collected : 2100
# ser_inwaiting : 0
# 2025-04-12 16:03:23.525291 Number of CSI data collected : 2200
# ser_inwaiting : 0
# 2025-04-12 16:03:27.945093 Number of CSI data collected : 2300
